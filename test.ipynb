# %%
import os

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\sahit\\AppData\\Roaming',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_3360_WQCGVIONCMKBFXZV',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'SAAHITHI',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CONDA_ALLOW_SOFTLINKS': 'false',
#         'CONDA_DEFAULT_ENV': 'sp25_taxi',
#         'CONDA_EXE': 'C:\\Users\\sahit\\anaconda3\\Scripts\\conda.exe',
#         'CONDA_EXES': '"C:\\Users\\sahit\\anaconda3\\Scripts\\conda.exe"  ',
#         'CONDA_PREFIX': 'C:\\Users\\sahit\\anaconda3\\envs\\sp25_taxi',
#         'CONDA_PREFIX_1': 'C:\\Users\\sahit\\anaconda3',
#         'CONDA_PROMPT_MODIFIER': '(sp25_taxi) ',
#         'CONDA_PYTHON_EXE': 'C:\\Users\\sahit\\anaconda3\\python.exe',
# ...

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\sahit\\AppData\\Roaming',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_3360_WQCGVIONCMKBFXZV',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'SAAHITHI',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CONDA_ALLOW_SOFTLINKS': 'false',
#         'CONDA_DEFAULT_ENV': 'sp25_taxi',
#         'CONDA_EXE': 'C:\\Users\\sahit\\anaconda3\\Scripts\\conda.exe',
#         'CONDA_EXES': '"C:\\Users\\sahit\\anaconda3\\Scripts\\conda.exe"  ',
#         'CONDA_PREFIX': 'C:\\Users\\sahit\\anaconda3\\envs\\sp25_taxi',
#         'CONDA_PREFIX_1': 'C:\\Users\\sahit\\anaconda3',
#         'CONDA_PROMPT_MODIFIER': '(sp25_taxi) ',
#         'CONDA_PYTHON_EXE': 'C:\\Users\\sahit\\anaconda3\\python.exe',
# ...
