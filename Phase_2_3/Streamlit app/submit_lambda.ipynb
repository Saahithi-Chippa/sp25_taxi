# %%
import boto3
import json
import time
from datetime import datetime

# Initialize the Lambda client
lambda_client = boto3.client('lambda')

# Lambda function name
function_name = 'etl_fetch_raw_taxi_data'

# Parameters
year = 2023
bucket_name = 's3_bucket_name'
s3_key_prefix = 'taxi/raw'
glue_job_name = 'etl-taxi-filter-and-transform'

# Create a timestamp for logging
timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Starting Lambda invocations at {timestamp}")

# Loop through all months of 2023
for month in range(1, 13):
    # Create the payload for the Lambda function
    payload = {
        'year': year,
        'month': month,
        'bucket_name': bucket_name,
        's3_key_prefix': s3_key_prefix,
        'glue_job_name': glue_job_name
    }
    print(f"\nInvoking Lambda for {year}-{month:02d}...")
    try:
        # Invoke the Lambda function
        response = lambda_client.invoke(
            FunctionName=function_name,
            InvocationType='RequestResponse', #Use 'Event' for asynchronus invocation
            Payload=json.dumps(payload)
        )
        # Parse the response
        response_payload = json.loads(response['Payload'].read().decode())
        # Print the response
        print(f"Status code: {response['StatusCode']}")
        print(f"Response: {json.dumps(response_payload, indent=2)}")
    except Exception as e:
        print(f"Error invoking Lambda for {year}-{month:02d}: {str(e)}")
    # Add a delay between invocations to avoid throttling
    if month < 12:
        print(f"Waiting 1 seconds before next invocation...")
        time.sleep(1)

print(f"\nCompleted all Lambda invocations at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Starting Lambda invocations at 2025-04-21 20:37:27
#
# Invoking Lambda for 2023-01...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=01/yellow_tripdata_2023-01.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_1560d3e6f9f6e5173f153dc0cda280228ef5b326a6481557234869d514288acf\"}"
# }
# Waiting 1 seconds before next invocation...
#
# Invoking Lambda for 2023-02...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=02/yellow_tripdata_2023-02.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_8ab8a303467c8d38bba0521f7bc89cacbbab594a914d42370a85f32b754dcb62\"}"
# }
# Waiting 1 seconds before next invocation...
#
# Invoking Lambda for 2023-03...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=03/yellow_tripdata_2023-03.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_81919890c236a1dd543ea30e45c7e0b88af8c955f18fcf001ceaf1a458a19814\"}"
# }
# Waiting 1 seconds before next invocation...
#
# Invoking Lambda for 2023-04...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=04/yellow_tripdata_2023-04.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_a6ef62a4b0f221eb78ada0b8a121bea3714173fdcc9f1061d48e4c478ac3896f\"}"
# }
# Waiting 1 seconds before next invocation...
#
# Invoking Lambda for 2023-05...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=05/yellow_tripdata_2023-05.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_0572641d27d14ee2572cac6055e25ca255707e08e12943d40a7ebec44a43a506\"}"
# }
# Waiting 1 seconds before next invocation...
#
# Invoking Lambda for 2023-06...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=06/yellow_tripdata_2023-06.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_731e7d1e416f6a2dac7356b06ba901d94307133bc4c03567510a1c4311f73280\"}"
# }
# Waiting 1 seconds before next invocation...
#
# Invoking Lambda for 2023-07...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=07/yellow_tripdata_2023-07.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_a70a9a5a261f532b7c6946e54d6d8dd5c47a221eb9e17ad010d88e878847a49a\"}"
# }
# Waiting 1 seconds before next invocation...
#
# Invoking Lambda for 2023-08...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=08/yellow_tripdata_2023-08.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_e63b44473c0af997aaefb02d49e48cf14fd53174dae663d63d6ae209b6e5d81c\"}"
# }
# Waiting 1 seconds before next invocation...
#
# Invoking Lambda for 2023-09...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=09/yellow_tripdata_2023-09.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_96d3a1b0273bcf2371003e2832832a5697e4ef8a5e2d40db110b36574e827990\"}"
# }
# Waiting 1 seconds before next invocation...
#
# Invoking Lambda for 2023-10...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=10/yellow_tripdata_2023-10.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_50ca7c8efe6bc0e234d657fd569f22d0a97df701f22098e38e4aac1bdf7c8be3\"}"
# }
# Waiting 1 seconds before next invocation...
#
# Invoking Lambda for 2023-11...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=11/yellow_tripdata_2023-11.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_956e42510f580ead35817f0c0d7f9a3d6b8205da8351cbd0d4359529170c33b5\"}"
# }
# Waiting 1 seconds before next invocation...
#
# Invoking Lambda for 2023-12...
# Status code: 200
# Response: {
#   "statusCode": 200,
#   "body": "{\"fetch_result\": \"File already exists in S3: s3://schippa-etl-b06fa59f-6b95-4049-acc2-2ab9390442ba/taxi/raw/year=2023/month=12/yellow_tripdata_2023-12.parquet\", \"glue_job\": \"Started Glue job etl-taxi-filter-and-transform with run ID: jr_becc5b55015e7b790313fde69c398d1b728c0a084a2462814f4f01b004107c0e\"}"
# }
#
# Completed all Lambda invocations at 2025-04-21 20:37:53
